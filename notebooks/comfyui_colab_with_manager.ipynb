# %% [markdown]
# Git clone the repo and install the requirements. (ignore the pip errors about protobuf)

# %% [markdown]
# ##INSTALL COMFY UI

# %%
# #@title Environment Setup

from pathlib import Path

OPTIONS = {}

USE_GOOGLE_DRIVE = True  #@param {type:"boolean"}
UPDATE_COMFY_UI = True  #@param {type:"boolean"}
USE_COMFYUI_MANAGER = True  #@param {type:"boolean"}
INSTALL_CUSTOM_NODES_DEPENDENCIES = True  #@param {type:"boolean"}
OPTIONS['USE_GOOGLE_DRIVE'] = USE_GOOGLE_DRIVE
OPTIONS['UPDATE_COMFY_UI'] = UPDATE_COMFY_UI
OPTIONS['USE_COMFYUI_MANAGER'] = USE_COMFYUI_MANAGER
OPTIONS['INSTALL_CUSTOM_NODES_DEPENDENCIES'] = INSTALL_CUSTOM_NODES_DEPENDENCIES

current_dir = !pwd
WORKSPACE = f"{current_dir[0]}/ComfyUI"

if OPTIONS['USE_GOOGLE_DRIVE']:
    # !echo "Mounting Google Drive..."
    # %cd /

    from google.colab import drive
    drive.mount('/content/drive')

    WORKSPACE = "/content/drive/MyDrive/ComfyUI"
    # %cd /content/drive/MyDrive

![ ! -d $WORKSPACE ] && echo -= Initial setup ComfyUI =- && git clone https://github.com/comfyanonymous/ComfyUI
# %cd $WORKSPACE

if OPTIONS['UPDATE_COMFY_UI']:
  # !echo -= Updating ComfyUI =-

  # Correction of the issue of permissions being deleted on Google Drive.
  ![ -f ".ci/nightly/update_windows/update_comfyui_and_python_dependencies.bat" ] && chmod 755 .ci/nightly/update_windows/update_comfyui_and_python_dependencies.bat
  ![ -f ".ci/nightly/windows_base_files/run_nvidia_gpu.bat" ] && chmod 755 .ci/nightly/windows_base_files/run_nvidia_gpu.bat
  ![ -f ".ci/update_windows/update_comfyui_and_python_dependencies.bat" ] && chmod 755 .ci/update_windows/update_comfyui_and_python_dependencies.bat
  ![ -f ".ci/update_windows_cu118/update_comfyui_and_python_dependencies.bat" ] && chmod 755 .ci/update_windows_cu118/update_comfyui_and_python_dependencies.bat
  ![ -f ".ci/update_windows/update.py" ] && chmod 755 .ci/update_windows/update.py
  ![ -f ".ci/update_windows/update_comfyui.bat" ] && chmod 755 .ci/update_windows/update_comfyui.bat
  ![ -f ".ci/update_windows/README_VERY_IMPORTANT.txt" ] && chmod 755 .ci/update_windows/README_VERY_IMPORTANT.txt
  ![ -f ".ci/update_windows/run_cpu.bat" ] && chmod 755 .ci/update_windows/run_cpu.bat
  ![ -f ".ci/update_windows/run_nvidia_gpu.bat" ] && chmod 755 .ci/update_windows/run_nvidia_gpu.bat

  # !git pull

# !echo -= Install dependencies =-
# !pip3 install accelerate
# !pip3 install einops transformers>=4.28.1 safetensors>=0.4.2 aiohttp pyyaml Pillow scipy tqdm psutil tokenizers>=0.13.3
# !pip3 install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu121
# !pip3 install torchsde
# !pip3 install kornia>=0.7.1 spandrel soundfile sentencepiece

if OPTIONS['USE_COMFYUI_MANAGER']:
  # %cd custom_nodes

  # Correction of the issue of permissions being deleted on Google Drive.
  ![ -f "ComfyUI-Manager/check.sh" ] && chmod 755 ComfyUI-Manager/check.sh
  ![ -f "ComfyUI-Manager/scan.sh" ] && chmod 755 ComfyUI-Manager/scan.sh
  ![ -f "ComfyUI-Manager/node_db/dev/scan.sh" ] && chmod 755 ComfyUI-Manager/node_db/dev/scan.sh
  ![ -f "ComfyUI-Manager/node_db/tutorial/scan.sh" ] && chmod 755 ComfyUI-Manager/node_db/tutorial/scan.sh
  ![ -f "ComfyUI-Manager/scripts/install-comfyui-venv-linux.sh" ] && chmod 755 ComfyUI-Manager/scripts/install-comfyui-venv-linux.sh
  ![ -f "ComfyUI-Manager/scripts/install-comfyui-venv-win.bat" ] && chmod 755 ComfyUI-Manager/scripts/install-comfyui-venv-win.bat

  ![ ! -d ComfyUI-Manager ] && echo -= Initial setup ComfyUI-Manager =- && git clone https://github.com/ltdrdata/ComfyUI-Manager
  # %cd ComfyUI-Manager
  # !git pull

# %cd $WORKSPACE

if OPTIONS['INSTALL_CUSTOM_NODES_DEPENDENCIES']:
  # !echo -= Install custom nodes dependencies =-
  # !pip install GitPython
  # !python custom_nodes/ComfyUI-Manager/cm-cli.py restore-dependencies
# Out:
# Mounting Google Drive...
# /
# Mounted at /content/drive
# /content/drive/MyDrive
# /content/drive/MyDrive/ComfyUI
# -= Updating ComfyUI =-
# remote: Enumerating objects: 53, done.
# remote: Counting objects: 100% (37/37), done.
# remote: Compressing objects: 100% (18/18), done.
# remote: Total 53 (delta 21), reused 20 (delta 19), pack-reused 16 (from 3)
# Unpacking objects: 100% (53/53), 164.85 KiB | 26.00 KiB/s, done.
# From https://github.com/comfyanonymous/ComfyUI
#    b53e247c..14b05228  master        -> origin/master
#  + 858cfd2d...90c2ef9a automation/comfyui-frontend-bump -> origin/automation/comfyui-frontend-bump  (forced update)
#  + f5963650...7518acd0 feat/partial-graph-execution -> origin/feat/partial-graph-execution  (forced update)
#  * [new branch]        fix/api-nodes/kling-remove-retired-models -> origin/fix/api-nodes/kling-remove-retired-models
#  * [new branch]        release/v0.30 -> origin/release/v0.30
#  * [new tag]           v0.30.1       -> v0.30.1
# ...

# %% [markdown]
# Download some models/checkpoints/vae or custom comfyui nodes (uncomment the commands for the ones you want)

# %%
# ======================================================================
# DESCARGA DE MODELOS PARA COMFYUI (RUTAS ABSOLUTAS CORREGIDAS)
# ======================================================================

# --- SDXL Checkpoints ---
# Ejemplos de workflows: https://comfyanonymous.github.io/ComfyUI_examples/sdxl/

# !wget -c https://huggingface.co/stabilityai/stable-diffusion-xl-base-1.0/resolve/main/sd_xl_base_1.0.safetensors -P /content/ComfyUI/models/checkpoints/
# !wget -c https://huggingface.co/stabilityai/stable-diffusion-xl-refiner-1.0/resolve/main/sd_xl_refiner_1.0.safetensors -P /content/ComfyUI/models/checkpoints/

# --- SDXL ReVision ---
#!wget -c https://huggingface.co/comfyanonymous/clip_vision_g/resolve/main/clip_vision_g.safetensors -P /content/ComfyUI/models/clip_vision/

# --- SD1.5 ---
#!wget -c https://huggingface.co/runwayml/stable-diffusion-v1-5/resolve/main/v1-5-pruned-emaonly.ckpt -P /content/ComfyUI/models/checkpoints/

# --- SD2 ---
#!wget -c https://huggingface.co/stabilityai/stable-diffusion-2-1-base/resolve/main/v2-1_512-ema-pruned.safetensors -P /content/ComfyUI/models/checkpoints/
#!wget -c https://huggingface.co/stabilityai/stable-diffusion-2-1/resolve/main/v2-1_768-ema-pruned.safetensors -P /content/ComfyUI/models/checkpoints/

# --- Modelos Anime SD1.5 ---
#!wget -c https://huggingface.co/WarriorMama777/OrangeMixs/resolve/main/Models/AbyssOrangeMix2/AbyssOrangeMix2_hard.safetensors -P /content/ComfyUI/models/checkpoints/
#!wget -c https://huggingface.co/WarriorMama777/OrangeMixs/resolve/main/Models/AbyssOrangeMix3/AOM3A1_orangemixs.safetensors -P /content/ComfyUI/models/checkpoints/
#!wget -c https://huggingface.co/WarriorMama777/OrangeMixs/resolve/main/Models/AbyssOrangeMix3/AOM3A3_orangemixs.safetensors -P /content/ComfyUI/models/checkpoints/
#!wget -c https://huggingface.co/Linaqruf/anything-v3.0/resolve/main/anything-v3-fp16-pruned.safetensors -P /content/ComfyUI/models/checkpoints/

# --- Waifu Diffusion 1.5 (Anime style SD2.x 768-v) ---
#!wget -c https://huggingface.co/waifu-diffusion/wd-1-5-beta3/resolve/main/wd-illusion-fp16.safetensors -P /content/ComfyUI/models/checkpoints/

# --- unCLIP models ---
#!wget -c https://huggingface.co/comfyanonymous/illuminatiDiffusionV1_v11_unCLIP/resolve/main/illuminatiDiffusionV1_v11-unclip-h-fp16.safetensors -P /content/ComfyUI/models/checkpoints/
#!wget -c https://huggingface.co/comfyanonymous/wd-1.5-beta2_unCLIP/resolve/main/wd-1-5-beta2-aesthetic-unclip-h-fp16.safetensors -P /content/ComfyUI/models/checkpoints/


# --- VAE ---
# !wget -c https://huggingface.co/stabilityai/sd-vae-ft-mse-original/resolve/main/vae-ft-mse-840000-ema-pruned.safetensors -P /content/ComfyUI/models/vae/
#!wget -c https://huggingface.co/WarriorMama777/OrangeMixs/resolve/main/VAEs/orangemix.vae.pt -P /content/ComfyUI/models/vae/
#!wget -c https://huggingface.co/hakurei/waifu-diffusion-v1-4/resolve/main/vae/kl-f8-anime2.ckpt -P /content/ComfyUI/models/vae/


# --- Loras ---
#!wget -c https://civitai.com/api/download/models/10350 -O /content/ComfyUI/models/loras/theovercomer8sContrastFix_sd21768.safetensors
#!wget -c https://civitai.com/api/download/models/10638 -O /content/ComfyUI/models/loras/theovercomer8sContrastFix_sd15.safetensors
#!wget -c https://huggingface.co/stabilityai/stable-diffusion-xl-base-1.0/resolve/main/sd_xl_offset_example-lora_1.0.safetensors -P /content/ComfyUI/models/loras/


# --- T2I-Adapter ---
#!wget -c https://huggingface.co/TencentARC/T2I-Adapter/resolve/main/models/t2iadapter_depth_sd14v1.pth -P /content/ComfyUI/models/controlnet/
#!wget -c https://huggingface.co/TencentARC/T2I-Adapter/resolve/main/models/t2iadapter_seg_sd14v1.pth -P /content/ComfyUI/models/controlnet/
#!wget -c https://huggingface.co/TencentARC/T2I-Adapter/resolve/main/models/t2iadapter_sketch_sd14v1.pth -P /content/ComfyUI/models/controlnet/
#!wget -c https://huggingface.co/TencentARC/T2I-Adapter/resolve/main/models/t2iadapter_keypose_sd14v1.pth -P /content/ComfyUI/models/controlnet/
#!wget -c https://huggingface.co/TencentARC/T2I-Adapter/resolve/main/models/t2iadapter_openpose_sd14v1.pth -P /content/ComfyUI/models/controlnet/
#!wget -c https://huggingface.co/TencentARC/T2I-Adapter/resolve/main/models/t2iadapter_color_sd14v1.pth -P /content/ComfyUI/models/controlnet/
#!wget -c https://huggingface.co/TencentARC/T2I-Adapter/resolve/main/models/t2iadapter_canny_sd14v1.pth -P /content/ComfyUI/models/controlnet/

# --- T2I Styles Model ---
#!wget -c https://huggingface.co/TencentARC/T2I-Adapter/resolve/main/models/t2iadapter_style_sd14v1.pth -P /content/ComfyUI/models/style_models/

# --- CLIPVision model (necesario para el modelo de estilos) ---
#!wget -c https://huggingface.co/openai/clip-vit-large-patch14/resolve/main/pytorch_model.bin -O /content/ComfyUI/models/clip_vision/clip_vit14.bin


# --- ControlNet ---
#!wget -c https://huggingface.co/comfyanonymous/ControlNet-v1-1_fp16_safetensors/resolve/main/control_v11e_sd15_ip2p_fp16.safetensors -P /content/ComfyUI/models/controlnet/
#!wget -c https://huggingface.co/comfyanonymous/ControlNet-v1-1_fp16_safetensors/resolve/main/control_v11e_sd15_shuffle_fp16.safetensors -P /content/ComfyUI/models/controlnet/
#!wget -c https://huggingface.co/comfyanonymous/ControlNet-v1-1_fp16_safetensors/resolve/main/control_v11p_sd15_canny_fp16.safetensors -P /content/ComfyUI/models/controlnet/
#!wget -c https://huggingface.co/comfyanonymous/ControlNet-v1-1_fp16_safetensors/resolve/main/control_v11f1p_sd15_depth_fp16.safetensors -P /content/ComfyUI/models/controlnet/
#!wget -c https://huggingface.co/comfyanonymous/ControlNet-v1-1_fp16_safetensors/resolve/main/control_v11p_sd15_inpaint_fp16.safetensors -P /content/ComfyUI/models/controlnet/
#!wget -c https://huggingface.co/comfyanonymous/ControlNet-v1-1_fp16_safetensors/resolve/main/control_v11p_sd15_lineart_fp16.safetensors -P /content/ComfyUI/models/controlnet/
#!wget -c https://huggingface.co/comfyanonymous/ControlNet-v1-1_fp16_safetensors/resolve/main/control_v11p_sd15_mlsd_fp16.safetensors -P /content/ComfyUI/models/controlnet/
#!wget -c https://huggingface.co/comfyanonymous/ControlNet-v1-1_fp16_safetensors/resolve/main/control_v11p_sd15_normalbae_fp16.safetensors -P /content/ComfyUI/models/controlnet/
#!wget -c https://huggingface.co/comfyanonymous/ControlNet-v1-1_fp16_safetensors/resolve/main/control_v11p_sd15_openpose_fp16.safetensors -P /content/ComfyUI/models/controlnet/
#!wget -c https://huggingface.co/comfyanonymous/ControlNet-v1-1_fp16_safetensors/resolve/main/control_v11p_sd15_scribble_fp16.safetensors -P /content/ComfyUI/models/controlnet/
#!wget -c https://huggingface.co/comfyanonymous/ControlNet-v1-1_fp16_safetensors/resolve/main/control_v11p_sd15_seg_fp16.safetensors -P /content/ComfyUI/models/controlnet/
#!wget -c https://huggingface.co/comfyanonymous/ControlNet-v1-1_fp16_safetensors/resolve/main/control_v11p_sd15_softedge_fp16.safetensors -P /content/ComfyUI/models/controlnet/
#!wget -c https://huggingface.co/comfyanonymous/ControlNet-v1-1_fp16_safetensors/resolve/main/control_v11p_sd15s2_lineart_anime_fp16.safetensors -P /content/ComfyUI/models/controlnet/
#!wget -c https://huggingface.co/comfyanonymous/ControlNet-v1-1_fp16_safetensors/resolve/main/control_v11u_sd15_tile_fp16.safetensors -P /content/ComfyUI/models/controlnet/

# --- ControlNet SDXL ---
#!wget -c https://huggingface.co/stabilityai/control-lora/resolve/main/control-LoRAs-rank256/control-lora-canny-rank256.safetensors -P /content/ComfyUI/models/controlnet/
#!wget -c https://huggingface.co/stabilityai/control-lora/resolve/main/control-LoRAs-rank256/control-lora-depth-rank256.safetensors -P /content/ComfyUI/models/controlnet/
#!wget -c https://huggingface.co/stabilityai/control-lora/resolve/main/control-LoRAs-rank256/control-lora-recolor-rank256.safetensors -P /content/ComfyUI/models/controlnet/
#!wget -c https://huggingface.co/stabilityai/control-lora/resolve/main/control-LoRAs-rank256/control-lora-sketch-rank256.safetensors -P /content/ComfyUI/models/controlnet/

# --- GLIGEN ---
#!wget -c https://huggingface.co/comfyanonymous/GLIGEN_pruned_safetensors/resolve/main/gligen_sd14_textbox_pruned_fp16.safetensors -P /content/ComfyUI/models/gligen/

# --- Modelos de Escalado ESRGAN ---
#!wget -c https://github.com/xinntao/Real-ESRGAN/releases/download/v0.1.0/RealESRGAN_x4plus.pth -P /content/ComfyUI/models/upscale_models/
#!wget -c https://huggingface.co/sberbank-ai/Real-ESRGAN/resolve/main/RealESRGAN_x2.pth -P /content/ComfyUI/models/upscale_models/
#!wget -c https://huggingface.co/sberbank-ai/Real-ESRGAN/resolve/main/RealESRGAN_x4.pth -P /content/ComfyUI/models/upscale_models/

print("🟢 ¡Proceso de descarga finalizado en las rutas absolutas correctas!")
# Out:
# --2026-07-18 00:34:19--  https://huggingface.co/stabilityai/stable-diffusion-xl-base-1.0/resolve/main/sd_xl_base_1.0.safetensors
# Resolving huggingface.co (huggingface.co)... 13.35.202.40, 13.35.202.97, 13.35.202.121, ...
# Connecting to huggingface.co (huggingface.co)|13.35.202.40|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
import os
from google.colab import drive

print("📁 Montando Google Drive...")
drive.mount('/content/drive')

print("\n🚀 Iniciando la descarga de los modelos directamente a Google Drive...")

# 1. Crear las carpetas de destino en Google Drive por si acaso no existen
# !mkdir -p /content/drive/MyDrive/ComfyUI/models/text_encoders
# !mkdir -p /content/drive/MyDrive/ComfyUI/models/loras
# !mkdir -p /content/drive/MyDrive/ComfyUI/models/diffusion_models
# !mkdir -p /content/drive/MyDrive/ComfyUI/models/vae

# 2. Descargar TEXT ENCODER (Qwen 3.4B)
print("\n🔹 Descargando Text Encoder (Qwen)...")
# !wget -c "https://huggingface.co/Comfy-Org/z_image_turbo/resolve/main/split_files/text_encoders/qwen_3_4b.safetensors" -O /content/drive/MyDrive/ComfyUI/models/text_encoders/qwen_3_4b.safetensors

# 3. Descargar LORA (Pixel Art Style)
print("\n🔹 Descargando LoRA (Pixel Art)...")
# !wget -c "https://huggingface.co/tarn59/pixel_art_style_lora_z_image_turbo/resolve/main/pixel_art_style_z_image_turbo.safetensors" -O /content/drive/MyDrive/ComfyUI/models/loras/pixel_art_style_z_image_turbo.safetensors

# 4. Descargar DIFFUSION MODEL (Z Image Turbo)
print("\n🔹 Descargando Diffusion Model (Z Image Turbo)...")
# !wget -c "https://huggingface.co/Comfy-Org/z_image_turbo/resolve/main/split_files/diffusion_models/z_image_turbo_bf16.safetensors" -O /content/drive/MyDrive/ComfyUI/models/diffusion_models/z_image_turbo_bf16.safetensors

# 5. Descargar VAE (Autoencoder base)
print("\n🔹 Descargando VAE (ae.safetensors)...")
# !wget -c "https://huggingface.co/Comfy-Org/z_image_turbo/resolve/main/split_files/vae/ae.safetensors" -O /content/drive/MyDrive/ComfyUI/models/vae/ae.safetensors

print("\n✅ ¡Descargas completadas con éxito en tu Google Drive! Ve a la interfaz de ComfyUI y dale al botón 'Refresh'.")
# Out:
# 📁 Montando Google Drive...
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#
# 🚀 Iniciando la descarga de los modelos directamente a Google Drive...
#
# 🔹 Descargando Text Encoder (Qwen)...
# --2026-08-03 02:05:55--  https://huggingface.co/Comfy-Org/z_image_turbo/resolve/main/split_files/text_encoders/qwen_3_4b.safetensors
# Resolving huggingface.co (huggingface.co)... 3.163.189.74, 3.163.189.90, 3.163.189.114, ...
# Connecting to huggingface.co (huggingface.co)|3.163.189.74|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %% [markdown]
# ##DESCARGA MODELOS NUEVO FLUJO DE TRABAJO CONSISTENTE

# %%
 #1. Crear directorios necesarios (por si no existen)
# !mkdir -p /content/ComfyUI/models/controlnet
# !mkdir -p /content/ComfyUI/models/clip_vision
# !mkdir -p /content/ComfyUI/models/ipadapter
# !mkdir -p /content/ComfyUI/models/ultralytics/bbox
# !mkdir -p /content/ComfyUI/models/sams
# !mkdir -p /content/ComfyUI/models/checkpoints

# --- RealVisXL V5.0 ---
# !wget -c https://huggingface.co/SG161222/RealVisXL_V5.0/resolve/main/RealVisXL_V5.0.safetensors -P /content/ComfyUI/models/checkpoints/

# --- 2. CONTROLNET OPENPOSE (Para SDXL) ---
# Modelo para que la IA entienda y replique la postura del cuerpo
# !wget -c https://huggingface.co/thibaud/controlnet-openpose-sdxl-1.0/resolve/main/OpenPoseXL2.safetensors -P /content/ComfyUI/models/controlnet/

# --- 3. CLIP VISION ENCODER (Para IP-Adapter) ---
# Es el "ojo" que analiza la foto de tu personaje y se la pasa a IP-Adapter
# !wget -c https://huggingface.co/h94/IP-Adapter/resolve/main/models/image_encoder/model.safetensors -O /content/ComfyUI/models/clip_vision/CLIP-ViT-H-14-laion2B-s32B-b79K.safetensors

# --- 4. MODELOS IP-ADAPTER (Para SDXL) ---
# Carga los rasgos faciales de tu personaje de referencia
# !wget -c https://huggingface.co/h94/IP-Adapter/resolve/main/sdxl_models/ip-adapter-plus-face_sdxl_vit-h.safetensors -P /content/ComfyUI/models/ipadapter/
# !wget -c https://huggingface.co/h94/IP-Adapter/resolve/main/sdxl_models/ip-adapter-plus_sdxl_vit-h.safetensors -P /content/ComfyUI/models/ipadapter/

# --- 5. DETECTORES PARA FACEDETAILER (Impact Pack) ---
# YOLO detecta dónde está el rostro en la imagen y SAM genera la máscara de precisión
# !wget -c https://huggingface.co/BlinkDL/densenet/resolve/main/face_yolov8m.pt -P /content/ComfyUI/models/ultralytics/bbox/
# !wget -c https://huggingface.co/litchi233/sam/resolve/main/sam_vit_b-01ec64.pth -P /content/ComfyUI/models/sams/
# Out:
# --2026-08-01 18:28:38--  https://huggingface.co/SG161222/RealVisXL_V5.0/resolve/main/RealVisXL_V5.0.safetensors
# Resolving huggingface.co (huggingface.co)... 13.35.202.40, 13.35.202.121, 13.35.202.34, ...
# Connecting to huggingface.co (huggingface.co)|13.35.202.40|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2026-08-01 18:28:38 ERROR 404: Not Found.
#
# --2026-08-01 18:28:38--  https://huggingface.co/thibaud/controlnet-openpose-sdxl-1.0/resolve/main/OpenPoseXL2.safetensors
# Resolving huggingface.co (huggingface.co)... 13.35.202.40, 13.35.202.121, 13.35.202.34, ...
# Connecting to huggingface.co (huggingface.co)|13.35.202.40|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
# 1. Crear las carpetas de destino correctas para Impact Pack en Google Drive
# !mkdir -p /content/drive/MyDrive/ComfyUI/models/ultralytics/bbox
# !mkdir -p /content/drive/MyDrive/ComfyUI/models/sams

# 2. Descargar el detector facial (YOLOv8 face)
print("\n🔹 Descargando Ultralytics YOLOv8 Face (face_yolov8m.pt)...")
# !wget -c "https://huggingface.co/Bingsu/adetailer/resolve/main/face_yolov8m.pt" -O /content/drive/MyDrive/ComfyUI/models/ultralytics/bbox/face_yolov8m.pt

print("\n🔹 Descargando Segment Anything Model (sam_vit_b_01ec64.pth)...")
# !wget -c "https://huggingface.co/ybelkada/segment-anything/resolve/main/checkpoints/sam_vit_b_01ec64.pth" -O /content/drive/MyDrive/ComfyUI/models/sams/sam_vit_b_01ec64.pth
# Out:
# 🔹 Descargando Ultralytics YOLOv8 Face (face_yolov8m.pt)...
# --2026-08-03 21:01:31--  https://huggingface.co/Bingsu/adetailer/resolve/main/face_yolov8m.pt
# Resolving huggingface.co (huggingface.co)... 18.164.174.55, 18.164.174.17, 18.164.174.118, ...
# Connecting to huggingface.co (huggingface.co)|18.164.174.55|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://us.gcp.cdn.hf.co/xet-bridge-us/644877453e498d66919f36ec/caabb1f274e56d11d815195c849679aefa391e603190b6d24ce17f570827b2c9?X-Xet-Cas-Uid=public&response-content-disposition=inline%3B+filename*%3DUTF-8%27%27face_yolov8m.pt%3B+filename%3D%22face_yolov8m.pt%22%3B&user_id=public&Expires=1785794491&Policy=...__&Signature=MEQCIGJ93XZTFJ1B2WB90z-Pk6xuQjtkKsTaN7hWM1VWSUjlAiAeXsBbCkrtVUVsqic9EBtQ6HoJhJaHGv%7EIXWW2dH4odA__&Key-Pair-Id=01KXEF4KZ1B6FV465MAWR4M21F [following]
# ...

# %%
print("\n🚀 Instalando ComfyUI-Impact-Pack en Google Drive...")

# 1. Asegurar que la carpeta custom_nodes exista
custom_nodes_path = "/content/drive/MyDrive/ComfyUI/custom_nodes"
os.makedirs(custom_nodes_path, exist_ok=True)

# 2. Clonar ComfyUI-Impact-Pack si no existe
impact_pack_path = os.path.join(custom_nodes_path, "ComfyUI-Impact-Pack")
if not os.path.exists(impact_pack_path):
    # !git clone https://github.com/ltdrdata/ComfyUI-Impact-Pack {impact_pack_path}
    print("✅ ComfyUI-Impact-Pack clonado con éxito.")
else:
    print("ℹ️ ComfyUI-Impact-Pack ya estaba instalado en tu Drive.")

# 3. Instalar dependencias requeridas por el Impact Pack por si acaso
print("\n🔹 Instalando dependencias del Impact Pack...")
# !pip install -r {impact_pack_path}/requirements.txt

print("\n✅ ¡Listo! Ahora reinicia el servidor de ComfyUI y al refrescar la interfaz verás todos los nodos de FaceDetailer.")
# Out:
# 🚀 Instalando ComfyUI-Impact-Pack en Google Drive...
# ℹ️ ComfyUI-Impact-Pack ya estaba instalado en tu Drive.
#
# 🔹 Instalando dependencias del Impact Pack...
# ...
#   Cloning https://github.com/facebookresearch/sam2 to /tmp/pip-req-build-20oytw07
#   Running command git clone --filter=blob:none --quiet https://github.com/facebookresearch/sam2 /tmp/pip-req-build-20oytw07
#   Resolved https://github.com/facebookresearch/sam2 to commit 2b90b9f5ceec907a1c18123530e92e794ad901a4
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#
# ✅ ¡Listo! Ahora reinicia el servidor de ComfyUI y al refrescar la interfaz verás todos los nodos de FaceDetailer.

# %% [markdown]
# ##Descargar Custom Nodes

# %%
# 1. Entrar a la carpeta custom_nodes en tu Google Drive
# %cd /content/drive/MyDrive/ComfyUI/custom_nodes/

# 2. Clonar SOLO los repositorios que te faltan
# !if [ ! -d "ComfyUI_IPAdapter_plus" ]; then git clone https://github.com/cubiq/ComfyUI_IPAdapter_plus.git; fi
# !if [ ! -d "comfyui_controlnet_aux" ]; then git clone https://github.com/Fannovel16/comfyui_controlnet_aux.git; fi
# !if [ ! -d "ComfyUI-Impact-Pack" ]; then git clone https://github.com/ltdrdata/ComfyUI-Impact-Pack.git; fi

# --- 3. Instalar librerías de Python en el entorno de Colab ---
# (Recuerda: las carpetas quedan en Drive, pero las librerías se deben instalar
# cada vez que inicies un entorno nuevo en Colab)
# %cd /content/drive/MyDrive/ComfyUI/
# !pip install -r custom_nodes/comfyui_controlnet_aux/requirements.txt
# !pip install -r custom_nodes/ComfyUI-Impact-Pack/requirements.txt
# Out:
# /content/drive/MyDrive/ComfyUI/custom_nodes
# Cloning into 'ComfyUI_IPAdapter_plus'...
# remote: Enumerating objects: 813, done.
# remote: Counting objects: 100% (429/429), done.
# remote: Compressing objects: 100% (132/132), done.
# remote: Total 813 (delta 404), reused 297 (delta 297), pack-reused 384 (from 2)
# Receiving objects: 100% (813/813), 4.73 MiB | 15.08 MiB/s, done.
# Resolving deltas: 100% (551/551), done.
# Cloning into 'comfyui_controlnet_aux'...
# remote: Enumerating objects: 5741, done.
# remote: Counting objects: 100% (2029/2029), done.
# remote: Compressing objects: 100% (447/447), done.
# remote: Total 5741 (delta 1741), reused 1582 (delta 1582), pack-reused 3712 (from 4)
# Receiving objects: 100% (5741/5741), 42.92 MiB | 15.81 MiB/s, done.
# Resolving deltas: 100% (3128/3128), done.
# Updating files: 100% (746/746), done.
# Cloning into 'ComfyUI-Impact-Pack'...
# remote: Enumerating objects: 6064, done.
# remote: Counting objects: 100% (766/766), done.
# ...

# %% [markdown]
# ## ComfyUI update requirements install

# %%
# !pip install -r /content/drive/MyDrive/ComfyUI/requirements.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.5/15.5 MB 67.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.4/29.4 MB 31.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 346.8/346.8 kB 17.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.4/67.4 kB 3.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 40.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.1/100.1 MB 7.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.4/17.4 MB 27.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.4/89.4 MB 9.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.1/89.1 MB 9.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.3/104.3 MB 8.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 264.7/264.7 kB 27.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.5/35.5 MB 49.5 MB/s eta 0:00:00
# ...

# %% [markdown]
# ##Install NGROK

# %%
# 1. Descargar la clave oficial del repositorio de Ngrok
# !curl -s https://ngrok-agent.s3.amazonaws.com/ngrok.asc | tee /etc/apt/trusted.gpg.d/ngrok.asc >/dev/null

# 2. Agregar el repositorio al listado del sistema
# !echo "deb https://ngrok-agent.s3.amazonaws.com buster main" | tee /etc/apt/sources.list.d/ngrok.list

# 3. Forzar actualización de repositorios e instalar Ngrok
# !apt-get update && apt-get install ngrok
# Out:
# deb https://ngrok-agent.s3.amazonaws.com buster main
# Get:1 https://cli.github.com/packages stable InRelease [3,917 B]
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:4 https://ngrok-agent.s3.amazonaws.com buster InRelease [20.3 kB]
# Get:5 https://cli.github.com/packages stable/main amd64 Packages [356 B]
# Hit:6 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:7 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:8 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:9 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ Packages [102 kB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:11 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [2,899 kB]
# ...

# %% [markdown]
# ##Install ultralytics

# %%
# !pip install ultralytics

# %% [markdown]
# ##Run ComfyUI with Ngrokon Google Drive

# %%
import subprocess
import threading
import time
import socket
import urllib.request
import json
import os

# 1. Asegurar ruta absoluta de trabajo en Google Drive
# %cd /content/drive/MyDrive/ComfyUI

# 2. Configurar Token de Ngrok de forma global
NGROK_TOKEN = "3GeYWdsVDY4LHfOEzKk3CjAi8Sr_49PRkiWwEJSs1z3uxXXW5"
os.system(f"ngrok config add-authtoken {NGROK_TOKEN}")

# Limpiar rigurosamente cualquier proceso de ngrok colgado de ejecuciones previas
os.system("pkill -f ngrok")
time.sleep(1)

PORT = 8188

def obtener_y_mostrar_enlace(port):
    print("⏳ Esperando que el motor interno de ComfyUI responda en el puerto 8188...")
    # Esperar a que el puerto interno 8188 de ComfyUI responda de verdad
    while True:
        time.sleep(1)
        sock = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
        result = sock.connect_ex(('127.0.0.1', port))
        sock.close()
        if result == 0:
            break

    print("⚡ Puerto detectado. Levantando túnel público de Ngrok...")
    # Lanzar el túnel HTTP de Ngrok en segundo plano
    subprocess.Popen(["ngrok", "http", str(port)], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

    # Sistema de reintentos para interrogar la API de Ngrok de forma segura
    for i in range(10):
        time.sleep(2)
        try:
            with urllib.request.urlopen('http://127.0.0.1:4040/api/tunnels') as response:
                data = json.loads(response.read().decode())
                if data['tunnels']:
                    url = data['tunnels'][0]['public_url']
                    print("\n" + "="*70)
                    print(f"🌍 ENLACE DEFINITIVO DE ACCESO A COMFYUI:")
                    print(f"👉 {url}")
                    print("="*70 + "\n")
                    return
        except Exception:
            pass

    print("\n❌ [ERROR] Ngrok no pudo entregar la URL a tiempo. Intenta detener e iniciar la celda de nuevo o revisa tu cuenta en ngrok.com")

# Lanzar el hilo encargado de capturar y mostrar la URL
threading.Thread(target=obtener_y_mostrar_enlace, daemon=True, args=(PORT,)).start()

print("🟢 Iniciando motor de ComfyUI... Mantén la celda corriendo, tu enlace aparecerá aquí abajo.")

# 3. Arrancar ComfyUI apuntando al archivo en tu Drive y abriendo los encabezados CORS
# !python /content/drive/MyDrive/ComfyUI/main.py --dont-print-server --listen 0.0.0.0 --port {PORT} --enable-cors-header "*"
# Out:
# /content/drive/MyDrive/ComfyUI
# ⏳ Esperando que el motor interno de ComfyUI responda en el puerto 8188...
# 🟢 Iniciando motor de ComfyUI... Mantén la celda corriendo, tu enlace aparecerá aquí abajo.
# [INFO] setup plugin alembic.autogenerate.schemas
# [INFO] setup plugin alembic.autogenerate.tables
# [INFO] setup plugin alembic.autogenerate.types
# [INFO] setup plugin alembic.autogenerate.constraints
# [INFO] setup plugin alembic.autogenerate.defaults
# [INFO] setup plugin alembic.autogenerate.comments
# [START] Security scan
# [INFO] [ComfyUI-Manager] Using `uv` as Python module for pip operations.
# Using Python 3.12.13 environment at: /usr
# [DONE] Security scan
# ## ComfyUI-Manager: installing dependencies done.
# ** ComfyUI startup time: 2026-08-03 21:27:25.413
# ** Platform: Linux
# ** Python version: 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]
# ** Python executable: /usr/bin/python3
# ** ComfyUI Path: /content/drive/MyDrive/ComfyUI
# ...

# %% [markdown]
# ### Run ComfyUI with Ngrok (Colab localhost)

# %%
import subprocess
import threading
import time
import socket
import urllib.request
import json
import os

# 1. Asegurar ruta absoluta de trabajo
# %cd /content/ComfyUI

# 2. Configurar Token de Ngrok de forma global
NGROK_TOKEN = "3GeYWdsVDY4LHfOEzKk3CjAi8Sr_49PRkiWwEJSs1z3uxXXW5"
os.system(f"ngrok config add-authtoken {NGROK_TOKEN}")

# Limpiar cualquier proceso previo colgado
os.system("killall ngrok 2>/dev/null")

PORT = 8188

def obtener_y_mostrar_enlace(port):
    # Esperar a que el puerto interno 8188 de ComfyUI responda
    while True:
        time.sleep(1)
        sock = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
        result = sock.connect_ex(('127.0.0.1', port))
        sock.close()
        if result == 0:
            break

    time.sleep(2)

    # Lanzar el túnel HTTP de Ngrok en segundo plano
    subprocess.Popen(["ngrok", "http", str(port)], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

    # Esperar un momento a que Ngrok negocie la URL con sus servidores
    time.sleep(3)

    # Consultar la API local de Ngrok para extraer la URL pública real
    try:
        with urllib.request.urlopen('http://127.0.0.1:4040/api/tunnels') as response:
            data = json.loads(response.read().decode())
            url = data['tunnels'][0]['public_url']
            print("\n" + "="*70)
            print(f"🌍 ENLACE DEFINITIVO DE ACCESO A COMFYUI:")
            print(f"👉 {url}")
            print("="*70 + "\n")
    except Exception as e:
        print("\n❌ [ERROR] Ngrok no pudo entregar la URL. Revisa tu panel en ngrok.com")

# Lanzar el hilo encargado de capturar y mostrar la URL
threading.Thread(target=obtener_y_mostrar_enlace, daemon=True, args=(PORT,)).start()

print("🟢 Iniciando motor de ComfyUI... Tu enlace aparecerá abajo en unos segundos.")

# 3. Arrancar ComfyUI abriendo los encabezados CORS para evitar el error 403
# !python /content/ComfyUI/main.py --dont-print-server --listen 0.0.0.0 --port {PORT} --enable-cors-header "*"
# Out:
# /content/ComfyUI
# 🟢 Iniciando motor de ComfyUI... Tu enlace aparecerá abajo en unos segundos.
# python3: can't open file '/content/ComfyUI/main.py': [Errno 2] No such file or directory

# %% [markdown]
# ### Run ComfyUI with localtunnel

# %%
# !npm install -g localtunnel

import subprocess
import threading
import time
import socket
import urllib.request

def iframe_thread(port):
  while True:
      time.sleep(0.5)
      sock = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
      result = sock.connect_ex(('127.0.0.1', port))
      if result == 0:
        break
      sock.close()
  print("\nComfyUI finished loading, trying to launch localtunnel (if it gets stuck here localtunnel is having issues)\n")

  print("The password/enpoint ip for localtunnel is:", urllib.request.urlopen('https://ipv4.icanhazip.com').read().decode('utf8').strip("\n"))
  p = subprocess.Popen(["lt", "--port", "{}".format(port)], stdout=subprocess.PIPE)
  for line in p.stdout:
    print(line.decode(), end='')


threading.Thread(target=iframe_thread, daemon=True, args=(8188,)).start()

# !python main.py --dont-print-server

# %% [markdown]
# ### Run ComfyUI with colab iframe (use only in case the previous way with localtunnel doesn't work)
#
# You should see the ui appear in an iframe. If you get a 403 error, it's your firefox settings or an extension that's messing things up.
#
# If you want to open it in another window use the link.
#
# Note that some UI features like live image previews won't work because the colab iframe blocks websockets.

# %%
import threading
import time
import socket
def iframe_thread(port):
  while True:
      time.sleep(0.5)
      sock = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
      result = sock.connect_ex(('127.0.0.1', port))
      if result == 0:
        break
      sock.close()
  from google.colab import output
  output.serve_kernel_port_as_iframe(port, height=1024)
  print("to open it in a window you can open this link here:")
  output.serve_kernel_port_as_window(port)

threading.Thread(target=iframe_thread, daemon=True, args=(8188,)).start()

# !python main.py --dont-print-server
